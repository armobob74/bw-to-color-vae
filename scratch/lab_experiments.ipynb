# %%
from skimage import color
from PIL import Image
import numpy as np

# %%
img = Image.open("./example_1_original.png")
img_recon = Image.open("example_1_recon.png")
display(img)
display(img_recon)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128>

# %%
from lab_utils import *

# %%
L = get_L(img)
ix = img_from_lab(L,0,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 L = get_L(img)
# ----> 2 ix = img_from_lab(L,0,0)
#
# File ~/Projects/bw-to-color-vae/scratch/lab_utils.py:36, in img_from_lab(L, a, b)
#      34 z[:,:,1] = a
#      35 z[:,:,2] = b
# ---> 36 img_rgb = color.lab2rgb(z, channel_axis=0)
#      37 return Image.fromarray((img_rgb * 255).astype(np.uint8))
#
# File ~/Projects/bw-to-color-vae/venv/lib/python3.8/site-packages/skimage/_shared/utils.py:359, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     356 kwargs["channel_axis"] = -1
#     358 # Call the function with the fixed arguments
# --> 359 out = func(*new_args, **kwargs)
#     360 if self.multichannel_output:
#     361     out = np.moveaxis(out, -1, channel_axis[0])
#
# File ~/Projects/bw-to-color-vae/venv/lib/python3.8/site-packages/skimage/color/colorconv.py:1222, in lab2rgb(lab, illuminant, observer, channel_axis)
#    1173 @channel_as_last_axis()
#    1174 def lab2rgb(lab, illuminant="D65", observer="2", *, channel_axis=-1):
#    1175     """Convert image in CIE-LAB to sRGB color space.
#    1176
#    1177     Parameters
#    (...)
#    1220     .. [2] https://en.wikipedia.org/wiki/CIELAB_color_space
#    1221     """
# -> 1222     xyz, n_invalid = _lab2xyz(lab, illuminant, observer)
#    1223     if n_invalid != 0:
#    1224         warn(
#    1225             "Conversion from CIE-LAB, via XYZ to sRGB color space resulted in "
#    1226             f"{n_invalid} negative Z values that have been clipped to zero",
#    1227             stacklevel=3,
#    1228         )
#
# File ~/Projects/bw-to-color-vae/venv/lib/python3.8/site-packages/skimage/color/colorconv.py:1099, in _lab2xyz(lab, illuminant, observer)
#    1085 def _lab2xyz(lab, illuminant, observer):
#    1086     """Convert CIE-LAB to XYZ color space.
#    1087
#    1088     Internal function for :func:`~.lab2xyz` and others. In addition to the
#    (...)
#    1097         Number of invalid pixels in the Z channel after conversion.
#    1098     """
# -> 1099     arr = _prepare_colorarray(lab, channel_axis=-1).copy()
#    1101     L, a, b = arr[..., 0], arr[..., 1], arr[..., 2]
#    1102     y = (L + 16.) / 116.
#
# File ~/Projects/bw-to-color-vae/venv/lib/python3.8/site-packages/skimage/color/colorconv.py:140, in _prepare_colorarray(arr, force_copy, channel_axis)
#     137 if arr.shape[channel_axis] != 3:
#     138     msg = (f'the input array must have size 3 along `channel_axis`, '
#     139            f'got {arr.shape}')
# --> 140     raise ValueError(msg)
#     142 float_dtype = _supported_float_type(arr.dtype)
#     143 if float_dtype == np.float32:
#
# ValueError: the input array must have size 3 along `channel_axis`, got (128, 3, 128)

# %%
from matplotlib import pyplot as plt
display(L)
# Out:
# array([[ 3.0169589 ,  2.72703586,  2.58522941, ...,  2.76195674,
#          3.00663604,  3.00663604],
#        [ 3.0169589 ,  3.0169589 ,  2.99717207, ...,  3.02642286,
#          2.74216991,  3.00663604],
#        [ 3.0169589 ,  3.3155412 ,  3.29575438, ...,  3.02642286,
#          2.98684921,  2.74216991],
#        ...,
#        [77.83820062, 85.74873338, 83.67520449, ..., 43.19228956,
#         44.90735191, 44.96778479],
#        [82.47587901, 79.58388862, 75.08309416, ..., 62.12891585,
#         48.9940554 , 46.9531997 ],
#        [78.65678232, 74.14523817, 72.17586407, ..., 82.43862567,
#         71.23618492, 56.57884248]])

# %%
L,a,b = get_lab(img)
L_recon, a_recon, b_recon = get_lab(img_recon)

# %%
img_from_lab(L,a,b)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_from_lab(L,a_recon,b_recon)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
